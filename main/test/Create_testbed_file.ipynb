# %% [markdown]
# # Notebook which creates a Json Testbed file

# %% [markdown]
# ### testbed = list(device-1, device-2, device-3, ...)

# %% [markdown]
# ### Defining the types for devices, compute, connection and some of the attributes

# %%
import json

# Testbed device types
# To do: In future add other devices: pi2, pi0, tx1, tk1. Other actuators like real drone devices/virtual drone devices
devices_types =['server', 'raspberry_pi_3', 'nvidia_jetson_tx2', 'google_vision_kit','smartphone']

# compute capabilities type in the testbed devices
# To do: Add other compute types
compute_types = ['cpu', 'gpu' , 'vpu']

# connection to reach the devices.
# To do: Add other connection types in future as needed
# May be an REST API and in attributed the interface details
connection_types = ['ssh']

# sensor types
sensor_types=['camera', 'audio']

# operating system types
os_types = ['ubuntu', 'windows', 'raspbian']

# %% [markdown]
# ### Defining Mininet server

# %%
# cpu compute attributes

## To do: later add more attributes
Mininet_server_cpu_compute_attributes={
    
    'no_of_cores':8,
     'manufacturer': 'intel'
}


# ssh connection attributes
Mininet_server_connection_attributes={
    'username':'root',
    'ip':'172.17.49.60',
    'password':'pwd'
}



Mininet_server = {
  'type' : devices_types[0],
    
   'attributes':
    {
    'compute': 
    [
        {
          'type': compute_types[0],
           'attributes':Mininet_server_cpu_compute_attributes
            
        },
        {
           "type": compute_types[1],
            'attributes':{}
        }
         
    ],
    'connection'  : 
        [
            {
                'type': connection_types[0],
                 'attributes': Mininet_server_connection_attributes
            }
        ],
    
     "os":
        {
            'type': os_types[0],
            'attributes': {}
        },
        
        'description' : 'General Linux Server used for mininet',
        
    }
}

# %% [markdown]
# ### Defining AirSim server

# %%
# cpu compute attributes
AirSim_server_cpu_compute_attributes={
    
    'no_of_cores':8,
     'manufacturer': 'intel'
}


# ssh connection attributes
AirSim_server_connection_attributes={
    'username':'root',
    'ip':'172.17.49.60',
    'password':'pwd'
}


AirSim_server = {
  'type' : devices_types[0],
    
   'attributes':
    {
    'compute': 
    [
        {
          'type': compute_types[0],
           'attributes':AirSim_server_cpu_compute_attributes
            
        },
        {
           "type": compute_types[1],
            'attributes':{ }
        }
         
    ],
    'connection'  : 
        [
            {
                'type': connection_types[0],
                 'attributes': AirSim_server_connection_attributes
            }
        ],
    
     "os":
        {
            'type': os_types[1],
            'attributes': {}
        },
        
        'description' : 'General Windows Server used for Airsim',
        
    }
}

# %% [markdown]
# ### Define Nvidia Jetson Tx2

# %%
# cpu compute attributes
Jetson_tx2_cpu_compute_attributes={
    
    'no_of_cores':4,
     'manufacturer': 'arm'
}


# ssh connection attributes
Jetson_tx2_connection_attributes={
    'username':'root',
    'ip':'172.17.49.60',
    'password':'pwd'
}

Jetson_tx2 = {
  'type' : devices_types[2],
    
   'attributes':
    {
    'compute': 
    [
        {
          'type': compute_types[0],
           'attributes':Jetson_tx2_cpu_compute_attributes
            
        },
        {
           "type": compute_types[1],
            'attributes':{ }
        }
         
    ],
        
    'connection'  : 
        [
            {
                'type': connection_types[0],
                 'attributes': Jetson_tx2_connection_attributes
            }
        ],
        
        'description' : 'Nvidia Jetson Tx2',
        
    }
}

# %% [markdown]
# ### Defining Google Vision Kit

# %%
# cpu compute attributes
Google_vision_kit_cpu_compute_attributes={
    
    'no_of_cores':1,
     'manufacturer': 'arm'
}


# ssh connection attributes
Google_vision_kit_connection_attributes={
    'username':'root',
    'ip':'172.17.49.60',
    'password':'pwd'
}


Google_vision_kit = {
  'type' : devices_types[3],
    
   'attributes':
    {
        'compute': 
    [
        {
          'type': compute_types[0],
           'attributes':Google_vision_kit_cpu_compute_attributes
            
        },
        {
           "type": compute_types[2],
            'attributes':{ }
        }
         
    ],
        
    'connection'  : 
        [
            {
                'type': connection_types[0],
                 'attributes': Google_vision_kit_connection_attributes
            }
        ],
        
        'sensor':
        [
            
          {
            'type': sensor_types[0],
             'attributes': {}
          }  
            
        ],
        
        'description' : 'Google vision kit',
        
    }
}

# %% [markdown]
# ### Defining raspberry pi-3 with Movidius-1 and camera

# %%
# cpu compute attributes
pi_3_vpu_cam_cpu_compute_attributes={
    
    'no_of_cores':2,
     'manufacturer': 'arm'
}


# ssh connection attributes
pi_3_vpu_cam_connection_attributes={
    'username':'root',
    'ip':'172.17.49.60',
    'password':'pwd'
}


pi_3_vpu_cam = {
  'type' : devices_types[1],
    
   'attributes':
    {
    'compute': 
    [
        {
          'type': compute_types[0],
           'attributes':pi_3_vpu_cam_cpu_compute_attributes
            
        },
        
        {
          'type': compute_types[2],
           'attributes':{}
            
        }
        
    ],
    'connection'  : 
        [
            {
                'type': connection_types[0],
                 'attributes': pi_3_vpu_cam_connection_attributes
            }
        ],
        
        'sensor':
        [
            
          {
            'type': sensor_types[0],
             'attributes': {}
          }  
            
        ],
        
    
     "os":
        {
            'type': os_types[2],
            'attributes': {}
        },
        
        'description' : 'Raspberry pi with camera and VPU',
        
    }
}

# %%
Testbed={}
Testbed['Devices']=[Mininet_server, AirSim_server, Jetson_tx2, Google_vision_kit, pi_3_vpu_cam]


Testbed_json = json.dumps(Testbed, indent=5)

# print("testbed definition")
# print('*'*100)
# print(Testbed_json)

# %% [markdown]
# ## Writing testbed definition to a file

# %%
outputfilename = "testbed.json"


with open(outputfilename, 'wb') as outfile:
    outfile.write(Testbed_json.encode())
    outfile.close()
